# %%
import os
path = "/Users/lfbarba/GitHub/deep-anomaly-detection/data/downsampled_cordierite"
folder = sorted([
                os.path.join(root, filename)
                for root, _, files in os.walk(path)
                for filename in files
                if filename.endswith(('.tiff', '.tif'))
            ])
folder[0]
# Out:
# '/Users/lfbarba/GitHub/deep-anomaly-detection/data/downsampled_cordierite/rec_16bit_phase_00003/cord_water_3_00003_0001.rec.16bit.tif'

# %%
from sdate.datasets.tiff_tomogram_dataset import TIFFDataset
import lovely_tensors as lt
lt.monkey_patch()

import numpy as np
import matplotlib.pyplot as plt

im_size = 512



kwargs = {
        "path": "/Users/lfbarba/GitHub/deep-anomaly-detection/data/downsampled_cordierite",
        "im_size":im_size,
        "train_transform": False,
        "rescale": im_size,
        "normalize_range":False,
    }
trainSet = TIFFDataset(**kwargs)
# Out:
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# Cell In [28], line 19
#       8 im_size = 512
#      12 kwargs = {
#      13         "path": "/Users/lfbarba/GitHub/deep-anomaly-detection/data/downsampled_cordierite",
#      14         "im_size":im_size,
#    (...)
#      17         "normalize_range":False,
#      18     }
# ---> 19 trainSet = TIFFDataset(**kwargs)
#
# File ~/GitHub/deep-anomaly-detection/sdate/datasets/tiff_tomogram_dataset.py:75, in TIFFDataset.__init__(self, path, im_size, rescale, clip_range, normalize_range, rotation_angle, contrast, train_transform, crop)
#      69 super().__init__(
#      70     rescale=rescale, clip_range=clip_range, normalize_range=normalize_range, rotation_angle=rotation_angle,
#      71     contrast=contrast, train_transform=train_transform, crop=crop
#      72 )
#      74 self.im_size = im_size
# ...

# %%
import random
index = random.randint(0, len(trainSet) - 1)
img = trainSet[index]
plt.imshow(img[0])
img

# %%
import torchvision.models as models
model = models.resnet34(pretrained=False, kwargs=**{"num_classes": 1000}).to(device)
# Out:
# /Users/lfbarba/opt/miniconda3/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/lfbarba/opt/miniconda3/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [29], line 2
#       1 import torchvision.models as models
# ----> 2 model = models.resnet34(pretrained=False, kwargs={"num_classes": 1000}).to(device)
#
# ...
